# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Creating a Dataframe

# %%
data = {
    'Name': ["Alice", "Bob", "Claire"],
    'Age': [25, 30, 27],
    'Gender': ["Female", "Male", "Female"],
    'City' : ['New York','Paris','Berlin'],
    'Salary': [50000,60000,70000]

}

df = pd.DataFrame(data)
df
# Out:
#      Name  Age  Gender      City  Salary
# 0   Alice   25  Female  New York   50000
# 1     Bob   30    Male     Paris   60000
# 2  Claire   27  Female    Berlin   70000

# %%
data_list = [
    ["Alice", 25, "Female", "New York", 50000],
    ["Bob", 30, "Male", "Paris", 60000],
    ["Claire", 27, "Female", "Berlin", 70000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name','Age,','Gender','City','Salary']
df2 = pd.DataFrame(data_list,columns=columns)
df2
# Out:
#      Name  Age,  Gender      City  Salary
# 0   Alice    25  Female  New York   50000
# 1     Bob    30    Male     Paris   60000
# 2  Claire    27  Female    Berlin   70000

# %% [markdown]
# #Selection and indexing of columns

# %%
df2
# Out:
#      Name  Age,  Gender      City  Salary
# 0   Alice    25  Female  New York   50000
# 1     Bob    30    Male     Paris   60000
# 2  Claire    27  Female    Berlin   70000

# %%
df[0] #here indexing doesn't works the name of the columns work
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1827/2658590012.py in <cell line: 0>()
# ----> 1 df[0] #here indexing doesn't works the name of the columns work
#
# ...

# %%
df2['Name']
# Out:
# 0     Alice
# 1       Bob
# 2    Claire
# Name: Name, dtype: object

# %%
df2['City']
# Out:
# 0    New York
# 1       Paris
# 2      Berlin
# Name: City, dtype: object

# %%
df2[['Name','City']]
# Out:
#      Name      City
# 0   Alice  New York
# 1     Bob     Paris
# 2  Claire    Berlin

# %% [markdown]
# #Creating a new Column

# %%
df2["Designation"] = ["Manager","Developer","Analyst"]
df2
# Out:
#      Name  Age,  Gender      City  Salary Designation
# 0   Alice    25  Female  New York   50000     Manager
# 1     Bob    30    Male     Paris   60000   Developer
# 2  Claire    27  Female    Berlin   70000     Analyst

# %% [markdown]
# #Removing a column

# %%
df2.drop('Designation') #automatic axis is 0 and that is row wise so throw an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1827/1994243344.py in <cell line: 0>()
# ----> 1 df2.drop('Designation') #automatic axis is 0 and that is row wise so throw an error
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df2 = df2.drop('Designation',axis = 1,inplace = True) #this is vertical and this does the job
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1827/485743635.py in <cell line: 0>()
# ----> 1 df2 = df2.drop('Designation',axis = 1,inplace = True) #this is vertical and this does the job
#       2 df2
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
# ...

# %%
df2.columns
# Out:
# Index(['Name', 'Age,', 'Gender', 'City', 'Salary'], dtype='object')

# %%
df2.drop(['City', 'Salary'], axis=1, inplace=True)
df2
# Out:
#      Name  Age,  Gender
# 0   Alice    25  Female
# 1     Bob    30    Male
# 2  Claire    27  Female

# %% [markdown]
# #Selecting a row

# %%
data_list = [
    ["Alice", 25, "Female", "New York", 50000],
    ["Bob", 30, "Male", "Paris", 60000],
    ["Claire", 27, "Female", "Berlin", 70000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name','Age','Gender','City','Salary']
df2 = pd.DataFrame(data_list,columns=columns)
df2
# Out:
#      Name  Age  Gender      City  Salary
# 0   Alice   25  Female  New York   50000
# 1     Bob   30    Male     Paris   60000
# 2  Claire   27  Female    Berlin   70000

# %%
df2.loc[0] #used for selecting rows
# Out:
# Name         Alice
# Age,            25
# Gender      Female
# City      New York
# Salary       50000
# Name: 0, dtype: object

# %%
df2.loc[[0,2]]
# Out:
#      Name  Age,  Gender      City  Salary
# 0   Alice    25  Female  New York   50000
# 2  Claire    27  Female    Berlin   70000

# %%
df2.iloc[2]
# Out:
# Name      Claire
# Age,          27
# Gender    Female
# City      Berlin
# Salary     70000
# Name: 2, dtype: object

# %% [markdown]
# #Subset of Rows and Columns

# %%
df.loc[[0,1]][['City','Salary']] #for selecting both rows and columns
# Out:
#        City  Salary
# 0  New York   50000
# 1     Paris   60000

# %%
df.loc[[1,2]][['Name','Age']]
# Out:
#      Name  Age
# 1     Bob   30
# 2  Claire   27

# %% [markdown]
# #Conditional Selection

# %%
df2
# Out:
#      Name  Age,  Gender      City  Salary
# 0   Alice    25  Female  New York   50000
# 1     Bob    30    Male     Paris   60000
# 2  Claire    27  Female    Berlin   70000

# %%
#only those people whose age is greater than 25
df2[df2["Age"]>25]
# Out:
#      Name  Age  Gender    City  Salary
# 1     Bob   30    Male   Paris   60000
# 2  Claire   27  Female  Berlin   70000

# %%
#only the perople whose age is grater than 25 and their city is  berlin
df2[(df2['Age'] > 25) & (df2['City'] == 'Berlin')]
# Out:
#      Name  Age  Gender    City  Salary
# 2  Claire   27  Female  Berlin   70000
